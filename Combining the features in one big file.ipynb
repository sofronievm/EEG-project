# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import os
import glob 
import scipy as scp

# path = 'G:/EEG Project/Sleep-EDF database data/features/time_features' #creates a list of all csv files
# data = [] # pd.concat takes a list of dataframes as an agrument
# for filename in glob.glob(os.path.join(path, '*.csv')):
#     frame = pd.read_csv(filename, index_col=0)
#     data.append(frame)

# bigframe = pd.concat(data, axis=1) #dont want pandas to try an align row indexes
# bigframe.to_csv("G:/EEG Project/Sleep-EDF database data/features/time_features/combined_features.csv")
# bigframe.head()
# Out:
#      Activity  Mobility  Complexity  kurtosis    Max     mean     Min  75%  \
# 0  324.646250  0.242982    2.934184  1.715940   82.0 -0.016000  -65.0  9.5
# 1  275.922833  0.273319    2.455417  0.843309   65.5 -0.105667  -60.0  9.5
# 2  448.055375  0.214343    3.116730  4.609353  114.0  0.167917 -117.5  9.5
# 3  234.392917  0.229851    2.774726  0.638107   58.5 -0.144000  -48.5  9.0
# 4  220.325792  0.244801    2.471135  1.116034   70.0  0.171250  -51.5  8.5
#
#    skewness        std   25%  ZCR
# 0  0.448721  18.017935 -10.5  566
# 1  0.341358  16.610589 -10.5  580
# 2  0.262410  21.166653 -10.5  546
# 3  0.121174  15.309219 -10.0  488
# 4  0.299613  14.842387  -9.0  543

# %%
path = 'G:\EEG Project\Sleep-EDF database data'
hypno = []
# target_path = 'G:\EEG Project\Sleep-EDF database data\CSV_hypnograms'
for idx, filename in enumerate(glob.glob(os.path.join(path, 'HypnogramAASM_subject*.txt'))):
    df = pd.read_table(filename)
    df.columns = ['scores']
    print(len(df['scores']))
    hypno.append(df)
bigframe = pd.concat(hypno)
bigframe.to_csv('G:\EEG Project\Sleep-EDF database data\CSV_hypnograms\hypnograms.csv')
# Out:
# 5768
# 6196
# 6050
# 5768
# 6668
# 6026
# 5040
# 5806
# 5982
# 6128
# 6202
# 5910
# 6870
# 6052
# 6318
# 6258
# 5984
# 6072
# 5820
# 6704
